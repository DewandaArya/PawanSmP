# %% [markdown]
# <a href="https://colab.research.google.com/github/DewandaArya/PawanSmP/blob/main/MineColab_Made_by_EXPOSUREEE_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
# ```
# Create a Minecraft Server on Google Colab!
#
# The script below will initiate your server. First, you will need to create the server to be able to use it - don't worry, the scripts below will do the majority of the work for you. Perhaps you want to change the server's region, check below.
#
# Original: https://github.com/thecoder-001/MineColab

# %% [markdown]
# # **1º Create the Server (Only do this the first time)**
#
# The code below will create your server and accept the EULA. When you use these scripts, your server will be ready to start.

# %% [markdown]
# **Download the Minecraft Server**
#
# The code below will download Paper, a type of high-performance Vanilla server that allows the use of plugins. If you want to use another type of server.jar, put it in the Drive folder manually.
#
# The server files will be saved on your Google Drive (in the Google account you choose or are using).

# %%
# Change "1.20.1" to the desired version.
# Available tested versions:
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8
# Newer versions might work too, however this isn't guaranteed.

version = '1.20.2'

# Choose server type. Currently available versions:
# - paper (Most vanilla. It's the same as SPIGOT, bukkit, etc.)
# - forge (For using MODS. It's basically FORGE) [Note, installation takes approximately 10-15 minutes, wait for "COMPLETED" after executing the first step.]
# - fabric (For playing Fabric. It's an alternative to Forge)

server_type = 'paper'

# Print experimental build warning -- no longer needed
# if version == '1.18' and server_type == 'paper':
#  print("<!> Paper 1.18 builds are still experimental. Make regular Backups!")

from google.colab import drive
import requests
import json

drive.mount('/content/drive')

# Create the directory which will be used for the server
! mkdir "/content/drive/My Drive/Minecraft-server"
# %cd "/content/drive/My Drive/Minecraft-server"

# Internal init...

a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
#print(a.json()["builds"][-1])
b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
#print(b.json()["downloads"]["application"]["name"])
print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])

paperURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

forgeURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge-installer.jar'}
url = {
    'paper': (paperURL),
    'fabric': 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.7.4/fabric-installer-0.7.4.jar',
    'forge': (forgeURL)
    }

print('Downloading to Google Drive...')

r = requests.get(url[server_type])

if r.status_code == 200:
  with open('/content/drive/My Drive/Minecraft-server/' + jar_name[server_type], 'wb') as f:
    f.write(r.content)
else:
  print('Error '+ str(r.status_code) + '! Most likely you entered an unsupported version. Try running the code again if you think that shouldn\'t have happened.')

# Running specific install path.
if server_type == 'fabric':
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
  # %cd "/content/drive/My Drive/Minecraft-server"
  # !java -jar forge-installer.jar --installServer

# Saving config
colabconfig = {"server_type": server_type,
               "server_version": version}
json.dump(colabconfig, open("colabconfig.json",'w'))

print('Completed!')  # todo: Would show even after erroring.

# Please read the file stored in your server folder before running this command.
# Also, go to https://www.minecraft.net/en-us/eula to read Minecraft's EULA.

# Make sure Drive is mounted
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/Minecraft-server"
# !echo "eula=true" >> eula.txt
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Minecraft-server
# https://papermc.io/api/v2/projects/paper/versions/1.20.2/builds/318/downloads/paper-1.20.2-318.jar
# Downloading to Google Drive...
# Completed!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server

# %% [markdown]
# # **-> Start the Minecraft server - Use this whenever you want to open it.**
#
# You can change the REGION in the code below; this is important for LAG and PING. Use regions closest to you. The default region is the United States, which is not recommended for countries in South America or Spain. For these, you can use regions like 'sa' (Brazil) and 'eu' (Europe). You can change it in the code below where indicated.
#
# **IMPORTANT:**
#
# The IP will change every time you restart the server.
# You need to enter your Ngrok TOKEN below. Visit https://dashboard.ngrok.com/auth to obtain your token (you need to have an account created on Ngrok).
# To enter a command through the console, you can do it here. Basically, the section below will be your console (where you will enter commands and see logs).
# It is advisable to keep the Google Colab tab open so that the server does not close. It may ask you to solve a captcha from time to time.

# %%
import os
import re
import json
import glob

# Update the package lists
# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, you might receive stale packages"

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory to the Minecraft server folder on Google Drive
# %cd "/content/drive/My Drive/Minecraft-server"
# !ls #list the directory contents (to verify that working directory was changed)

# Import config file.
if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"} # using default, if config doesn't exist.
  json.dump(colabconfig, open("colabconfig.json",'w'))

# Install OpenJDK 17
# !wget -qO - https://adoptopenjdk.jfrog.io/adoptopenjdk/api/gpg/key/public | sudo apt-key add -
# !sudo add-apt-repository --yes https://adoptopenjdk.jfrog.io/adoptopenjdk/deb/ &>/dev/null || echo "Failed to add repo. Still can be ignored if openjdk17 gets installed."
if colabconfig["server_type"] == "forge":
   version = colabconfig["server_version"]
   if colabconfig["server_version"] < "1.17":
    # !sudo apt-get install openjdk-15-jre-headless &>/dev/null && echo "Yay! Openjdk15 has been successfully installed." || echo "Failed to install OpenJdk15."
   else:
    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."
else:
  # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."

#Perform java version check
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "17" :
  print("Openjdk17 is working correctly, you are good to go.")
else:
  print("Openjdk17 doesn't seem to be installed or isn't working, falling back to java", java_ver[0], ". You might experience reduced performance. Minecraft 1.17 and above might fail to launch.")

# Server jar names.
jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar'}
jar_name = jar_list[colabconfig["server_type"]]

# Java arguments.
if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = "" # aiker's flags might negatively impact performance on non-paper servers.
memory_allocation = "-Xms8704M -Xmx8704M"

# Choose the tunnel service you want to use
# Available options: ngrok, argo, playit
tunnel_service = "playit"
print("Using", tunnel_service)

# !sudo help

# !java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# apt cache successfully updated
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server
# banned-ips.json      config	      libraries        server.properties     world
# banned-players.json  current	      logs	       spigot.yml	     world_nether
# bukkit.yml	     current_nether   ops.json	       usercache.json	     world_the_end
# cache		     current_the_end  permissions.yml  version_history.json
# colabconfig.json     eula.txt	      plugins	       versions
# commands.yml	     help.yml	      server.jar       whitelist.json
# Yay! Openjdk17 has been successfully installed.
# Openjdk17 is working correctly, you are good to go.
# Using playit
# sudo: help: command not found
# Starting org.bukkit.craftbukkit.Main
# *** Warning, you've not updated in a while! ***
# *** Please download a new build as per instructions from https://papermc.io/downloads/paper ***
# System Info: Java 17 (OpenJDK 64-Bit Server VM 17.0.10+7-Ubuntu-122.04.1) Host: Linux 6.1.58+ (amd64)
# Loading libraries, please wait...
# [14:16:32 ERROR]: [DirectoryProviderSource] Error loading plugin: Directory 'plugins/zItemStacker.jar' failed to load!
# java.lang.RuntimeException: Directory 'plugins/zItemStacker.jar' failed to load!
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.registerProviders(FileProviderSource.java:59) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.lambda$registerProviders$1(DirectoryProviderSource.java:34) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.util.stream.ForEachOps$ForEachOp$OfRef.accept(ForEachOps.java:183) ~[?:?]
# 	at java.util.stream.ReferencePipeline$2$1.accept(ReferencePipeline.java:179) ~[?:?]
# 	at java.util.stream.ReferencePipeline$3$1.accept(ReferencePipeline.java:197) ~[?:?]
# 	at java.util.Iterator.forEachRemaining(Iterator.java:133) ~[?:?]
# 	at java.util.Spliterators$IteratorSpliterator.forEachRemaining(Spliterators.java:1845) ~[?:?]
# 	at java.util.stream.AbstractPipeline.copyInto(AbstractPipeline.java:509) ~[?:?]
# 	at java.util.stream.AbstractPipeline.wrapAndCopyInto(AbstractPipeline.java:499) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp.evaluateSequential(ForEachOps.java:150) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp$OfRef.evaluateSequential(ForEachOps.java:173) ~[?:?]
# 	at java.util.stream.AbstractPipeline.evaluate(AbstractPipeline.java:234) ~[?:?]
# 	at java.util.stream.ReferencePipeline.forEach(ReferencePipeline.java:596) ~[?:?]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.registerProviders(DirectoryProviderSource.java:32) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.registerProviders(DirectoryProviderSource.java:14) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.util.EntrypointUtil.registerProvidersFromSource(EntrypointUtil.java:14) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.PluginInitializerManager.load(PluginInitializerManager.java:100) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.Main.main(Main.java:134) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.craftbukkit.Main.main(Main.java:325) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paperclip.Paperclip.lambda$main$0(Paperclip.java:42) ~[app:?]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.util.zip.ZipException: zip END header not found
# 	at java.util.zip.ZipFile$Source.findEND(ZipFile.java:1633) ~[?:?]
# 	at java.util.zip.ZipFile$Source.initCEN(ZipFile.java:1641) ~[?:?]
# 	at java.util.zip.ZipFile$Source.<init>(ZipFile.java:1479) ~[?:?]
# 	at java.util.zip.ZipFile$Source.get(ZipFile.java:1441) ~[?:?]
# 	at java.util.zip.ZipFile$CleanableResource.<init>(ZipFile.java:718) ~[?:?]
# 	at java.util.zip.ZipFile.<init>(ZipFile.java:252) ~[?:?]
# 	at java.util.zip.ZipFile.<init>(ZipFile.java:181) ~[?:?]
# 	at java.util.jar.JarFile.<init>(JarFile.java:346) ~[?:?]
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.registerProviders(FileProviderSource.java:51) ~[paper-1.20.2.jar:git-Paper-318]
# 	... 20 more
# [14:16:47 INFO]: Environment: Environment[accountsHost=https://api.mojang.com, sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [14:16:50 INFO]: Loaded 1174 recipes
# [14:16:50 INFO]: Loaded 1271 advancements
# [14:16:50 INFO]: Starting minecraft server version 1.20.2
# [14:16:50 WARN]: ****************************
# [14:16:50 WARN]: YOU ARE RUNNING THIS SERVER AS AN ADMINISTRATIVE OR ROOT USER. THIS IS NOT ADVISED.
# [14:16:50 WARN]: YOU ARE OPENING YOURSELF UP TO POTENTIAL RISKS WHEN DOING THIS.
# [14:16:50 WARN]: FOR MORE INFORMATION, SEE https://madelinemiller.dev/blog/root-minecraft-server/
# [14:16:50 WARN]: ****************************
# [14:16:50 INFO]: Loading properties
# [14:16:51 INFO]: This server is running Paper version git-Paper-318 (MC: 1.20.2) (Implementing API version 1.20.2-R0.1-SNAPSHOT) (Git: 9271ee7)
# [14:16:52 INFO]: Server Ping Player Sample Count: 12
# [14:16:52 INFO]: Using 4 threads for Netty based IO
# [14:16:52 WARN]: [!] The timings profiler has been enabled but has been scheduled for removal from Paper in the future.
#     We recommend installing the spark profiler as a replacement: https://spark.lucko.me/
#     For more information please visit: https://github.com/PaperMC/Paper/issues/8948
# [14:16:52 INFO]: [ChunkTaskScheduler] Chunk system is using 1 I/O threads, 1 worker threads, and gen parallelism of 1 threads
# [14:16:53 INFO]: Default game type: SURVIVAL
# [14:16:53 INFO]: Generating keypair
# [14:16:53 INFO]: Starting Minecraft server on *:25565
# [14:16:53 INFO]: Using epoll channel type
# [14:16:53 INFO]: Paper: Using libdeflate (Linux x86_64) compression from Velocity.
# [14:16:53 INFO]: Paper: Using OpenSSL 3.0.x (Linux x86_64) cipher from Velocity.
# [14:16:55 INFO]: [ViaVersion] Loading server plugin ViaVersion v4.9.3-SNAPSHOT
# [14:16:55 INFO]: [ViaVersion] ViaVersion 4.9.3-SNAPSHOT is now loaded. Registering protocol transformers and injecting...
# [14:16:57 INFO]: [ViaVersion] Loading block connection mappings ...
# [14:16:57 INFO]: [ViaVersion] Using FastUtil Long2ObjectOpenHashMap for block connections
# [14:16:57 INFO]: [LuckPerms] Loading server plugin LuckPerms v5.4.108
# [14:16:58 INFO]: [Vault] Loading server plugin Vault v1.7.3-b131
# [14:16:58 INFO]: [Multiverse-Core] Loading server plugin Multiverse-Core v4.3.12
# [14:16:58 INFO]: [PlaceholderAPI] Loading server plugin PlaceholderAPI v2.11.5
# [14:16:58 INFO]: [Essentials] Loading server plugin Essentials v2.20.1
# [14:16:58 INFO]: [DiscordSRV] Loading server plugin DiscordSRV v1.27.0
# [14:16:58 INFO]: [Geyser-Spigot] Loading server plugin Geyser-Spigot v2.2.2-SNAPSHOT
# [14:16:59 INFO]: [Geyser-Spigot] Loading extensions...
# [14:16:59 INFO]: [Geyser-Spigot] Loaded 0 extension(s)
# [14:16:59 INFO]: [SkinsRestorer] Loading server plugin SkinsRestorer v15.0.2-SNAPSHOT
# [14:16:59 INFO]: [TreeAssist] Loading server plugin TreeAssist v7.3.51
# [14:16:59 INFO]: [TreeAssist] Loading main config file: /config.yml
# [14:16:59 INFO]: [TreeAssist] Config created: CHERRY
# [14:16:59 WARN]: [TreeAssist] Could not save cherry.yml to plugins/TreeAssist/trees/overworld/cherry.yml because cherry.yml already exists.
# [14:16:59 WARN]: [TreeAssist] Invalid Material in TreeConfig default.yml - Node Natural Blocks entry invalid: minecraft:short_grass
# [14:17:00 INFO]: [ForestPlant] Loading server plugin ForestPlant vv1.0.7
# [14:17:00 INFO]: [GriefPrevention] Loading server plugin GriefPrevention v16.18.1
# [14:17:00 INFO]: [SlimeablePistons] Loading server plugin SlimeablePistons v${1.1}
# [14:17:00 INFO]: [PlayerCheck] Loading server plugin PlayerCheck v1.0-SNAPSHOT
# [14:17:00 INFO]: [AngelChest] Loading server plugin AngelChest v11.0.1
# [14:17:00 INFO]: [Multiverse-Inventories] Loading server plugin Multiverse-Inventories v4.2.6
# [14:17:00 INFO]: [ChatItem] Loading server plugin ChatItem v2.4.9
# [14:17:00 INFO]: [EssentialsChat] Loading server plugin EssentialsChat v2.20.1
# [14:17:00 INFO]: [BedrockParity] Loading server plugin BedrockParity v2.0.0
# [14:17:00 INFO]: [playit-gg] Loading server plugin playit-gg v0.1.4
# [14:17:00 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [14:17:00 INFO]: [LuckPerms] Enabling LuckPerms v5.4.108
# [14:17:01 INFO]:         __
# [14:17:01 INFO]:   |    |__)   LuckPerms v5.4.108
# [14:17:01 INFO]:   |___ |      Running on Bukkit - Paper
# [14:17:01 INFO]:
# [14:17:01 INFO]: [LuckPerms] Loading configuration...
# [14:17:02 INFO]: [LuckPerms] Loading storage provider... [H2]
# [14:17:03 INFO]: [LuckPerms] Loading internal permission managers...
# [14:17:03 INFO]: [LuckPerms] Performing initial data load...
# [14:17:04 INFO]: [LuckPerms] Successfully enabled. (took 3057ms)
# [14:17:04 INFO]: [Vault] Enabling Vault v1.7.3-b131
# [14:17:04 INFO]: [Vault] [Economy] Essentials Economy found: Waiting
# [14:17:04 INFO]: [Vault] [Permission] SuperPermissions loaded as backup permission system.
# [14:17:04 INFO]: [Vault] Enabled Version 1.7.3-b131
# [14:17:04 INFO]: [LuckPerms] Registered Vault permission & chat hook.
# [14:17:04 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.2-SNAPSHOT
# [14:17:09 INFO]: [SkinsRestorer] Detected Minecraft v1_20_R2, using MappingSpigotSkinRefresher.
# [14:17:10 INFO]: [PlaceholderAPI] Successfully registered internal expansion: skinsrestorer [15.0.2-SNAPSHOT]
# [14:17:10 INFO]: [SkinsRestorer] PlaceholderAPI expansion registered!
# [14:17:10 INFO]: [SkinsRestorer] Using paper join listener!
# [14:17:10 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [14:17:10 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [14:17:10 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [14:17:10 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [14:17:10 INFO]: Preparing level "current"
# [14:17:10 INFO]: [SkinsRestorer] [GitHubUpdate] Downloading update...
# [14:17:10 INFO]: [SkinsRestorer] ----------------------------------------------
# [14:17:10 INFO]: [SkinsRestorer]     +==================+
# [14:17:10 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [14:17:10 INFO]: [SkinsRestorer]     |------------------|
# [14:17:10 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [14:17:10 INFO]: [SkinsRestorer]     +==================+
# [14:17:10 INFO]: [SkinsRestorer] ----------------------------------------------
# [14:17:10 INFO]: [SkinsRestorer]     Current version: 15.0.2-SNAPSHOT
# [14:17:10 INFO]: [SkinsRestorer]     Commit: 26f171e
# [14:17:10 INFO]: [SkinsRestorer]     New version: 15.0.7
# [14:17:10 INFO]: [SkinsRestorer]     A new version is available! Downloading it now...
# [14:17:10 INFO]: [SkinsRestorer] ----------------------------------------------
# [14:17:11 INFO]: Preparing start region for dimension minecraft:overworld
# [14:17:12 INFO]: [SkinsRestorer] [GitHubUpdate] Update saved as SkinsRestorer.jar
# [14:17:12 INFO]: [SkinsRestorer] [GitHubUpdate] The update will be loaded on the next server restart
# [14:17:12 INFO]: Time elapsed: 561 ms
# [14:17:12 INFO]: Preparing start region for dimension minecraft:the_nether
# [14:17:12 INFO]: Time elapsed: 169 ms
# [14:17:12 INFO]: Preparing start region for dimension minecraft:the_end
# [14:17:12 INFO]: Time elapsed: 109 ms
# [14:17:12 INFO]: [ViaVersion] Enabling ViaVersion v4.9.3-SNAPSHOT
# [14:17:12 INFO]: [ViaVersion] ViaVersion detected server version: 1.20.2 (764)
# [14:17:12 INFO]: [Multiverse-Core] Enabling Multiverse-Core v4.3.12
# [14:17:12 WARN]: [Multiverse-Core] "Multiverse-Core v4.3.12" has registered a listener for org.bukkit.event.entity.EntityCreatePortalEvent on method "public void com.onarandombox.MultiverseCore.listeners.MVPortalListener.entityPortalCreate(org.bukkit.event.entity.EntityCreatePortalEvent)", but the event is Deprecated. "Server performance will be affected"; please notify the authors [dumptruckman, Rigby, fernferret, lithium3141, main--].
# [14:17:12 INFO]: [Multiverse-Core] §aWe are aware of the warning about the deprecated event. There is no alternative that allows us to do what we need to do and performance impact is negligible. It is safe to ignore.
# [14:17:13 INFO]: [Multiverse-Core] 3 - World(s) loaded.
# [14:17:13 WARN]: [Multiverse-Core] Buscript failed to load! The script command will be disabled! If you would like not to see this message, use `/mv conf enablebuscript false` to disable Buscript from loading.
# [14:17:13 INFO]: [Multiverse-Core] Version 4.3.12 (API v24) Enabled - By dumptruckman, Rigby, fernferret, lithium3141 and main--
# [14:17:13 INFO]: [PlaceholderAPI] Enabling PlaceholderAPI v2.11.5
# [14:17:13 INFO]: [PlaceholderAPI] Fetching available expansion information...
# [14:17:13 INFO]: [Essentials] Enabling Essentials v2.20.1
# [14:17:13 ERROR]: [Essentials] You are running an unsupported server version!
# [14:17:15 INFO]: [Essentials] Creating config from template: plugins/Essentials/config.yml
# [14:17:15 WARN]: [Essentials] Missing userdata folder, aborting
# [14:17:15 INFO]: [Essentials] Creating config from template: plugins/Essentials/kits.yml
# [14:17:15 INFO]: [Essentials] Attempting to convert old kits in config.yml to new kits.yml
# [14:17:15 INFO]: [Essentials] No kits found to migrate.
# [14:17:15 INFO]: [Essentials] Starting Essentials ban format conversion
# [14:17:15 INFO]: [Essentials] Attempting to migrate ignore list to UUIDs
# [14:17:15 INFO]: [Essentials] Attempting to migrate legacy userdata keys to Configurate
# [14:17:15 INFO]: [Essentials] Creating config from template: plugins/Essentials/worth.yml
# [14:17:15 INFO]: [Essentials] Creating config from template: plugins/Essentials/tpr.yml
# [14:17:16 INFO]: [Essentials] Loaded 39094 items from items.json.
# [14:17:16 INFO]: [Essentials] Creating config from template: plugins/Essentials/custom_items.yml
# [14:17:16 INFO]: [Essentials] Using locale en_US
# [14:17:16 INFO]: [Essentials] ServerListPingEvent: Spigot iterator API
# [14:17:16 INFO]: [Essentials] Starting Metrics. Opt-out using the global bStats config.
# [14:17:16 INFO]: [Vault] [Economy] Essentials Economy hooked.
# [14:17:16 INFO]: [Essentials] Using Vault based permissions (LuckPerms)
# [14:17:16 INFO]: [DiscordSRV] Enabling DiscordSRV v1.27.0
# [14:17:16 INFO]: [Geyser-Spigot] Enabling Geyser-Spigot v2.2.2-SNAPSHOT
# [14:17:16 INFO]: [TreeAssist] Enabling TreeAssist v7.3.51
# [14:17:16 INFO]: [TreeAssist] sending full Metrics! You can deactivate this in the config.yml
# [14:17:16 INFO]: [TreeAssist] debugging: off
# [14:17:16 INFO]: [PlaceholderAPI] Successfully registered internal expansion: ta [0.0.1]
# [14:17:16 INFO]: [ForestPlant] Enabling ForestPlant vv1.0.7
# [14:17:16 INFO]: [TreeAssist] Checking for updates...
# [14:17:16 INFO]: [ForestPlant] INFO : Using lang 'en'
# [14:17:16 INFO]: [ForestPlant] WARN : messages_en.yml does not exist!
# [14:17:16 INFO]: [ForestPlant] INFO : messages_en.yml loaded successfully!
# [14:17:17 INFO]: [GriefPrevention] Enabling GriefPrevention v16.18.1
# [14:17:17 INFO]: [GriefPrevention] Finished loading configuration.
# [14:17:17 INFO]: [GriefPrevention] 0 total claims loaded.
# [14:17:17 INFO]: [GriefPrevention] Customizable messages loaded.
# [14:17:17 INFO]: [GriefPrevention] Finished loading data (File Mode).
# [14:17:17 INFO]: [GriefPrevention] Boot finished.
# [14:17:17 INFO]: [SlimeablePistons] Enabling SlimeablePistons v${1.1}
# [14:17:17 INFO]: [DiscordSRV] DiscordSRV is up-to-date. (6405e850eea61a4b9bf4f0d0cbb80fe20b3cfb90)
# [14:17:17 INFO]: [PlayerCheck] Enabling PlayerCheck v1.0-SNAPSHOT
# [14:17:17 INFO]: [AngelChest] Enabling AngelChest v11.0.1
# [14:17:18 INFO]: [AngelChest] groups.yml does not exist, skipping custom group settings.
# [14:17:18 INFO]: [AngelChest] blacklist.yml does not exist, disabling item blacklist.
# [14:17:18 INFO]: [AngelChest] Not using premium version, disabling Graveyards feature
# [14:17:18 INFO]: [PlaceholderAPI] Successfully registered internal expansion: angelchest [GENERIC]
# [14:17:18 INFO]: [AngelChest] Successfully hooked into Vault and the EconomyProvider, enabling economy functions.
# [14:17:18 INFO]: [AngelChest] [ACF] Enabled Asynchronous Tab Completion Support!
# [14:17:18 INFO]: [DiscordSRV] [JDA] Login Successful!
# [14:17:18 INFO]: [AngelChest] Successfully enabled AngelChest v11.0.1 (Premium: false)
# [14:17:18 INFO]: [Multiverse-Inventories] Enabling Multiverse-Inventories v4.2.6
# [14:17:18 INFO]: [Multiverse-Inventories 4.2.6] enabled.
# [14:17:18 INFO]: [ChatItem] Enabling ChatItem v2.4.9
# [14:17:18 INFO]: [ChatItem] Detected server version: v1_20
# [14:17:19 INFO]: [ChatItem] Loading own packet system.
# [14:17:19 INFO]: [ChatItem] Loaded 3 getter for base components.
# [14:17:19 INFO]: [ChatItem] Save method founded: b. Use ComponentBuilder's method.
# [14:17:19 INFO]: [ChatItem] Manager automatically chosen: PacketEditing (packet), ChatListener (chat)
# [14:17:19 INFO]: [ChatItem] Load DiscordSRV support.
# [14:17:19 INFO]: [DiscordSRV] [JDA] Connected to WebSocket
# [14:17:19 INFO]: [DiscordSRV] [JDA] Finished Loading!
# [14:17:19 INFO]: [DiscordSRV] Found server G:🌸Pawan'SMP(1152814325111722115)
# [14:17:19 INFO]: [DiscordSRV] - TC:moderator-only(1170360612866502776)
# [14:17:19 INFO]: [DiscordSRV] - TC:server-console(1179704250822037565)
# [14:17:19 INFO]: [DiscordSRV] - TC:ℹ╎info(1152856245498294282)
# [14:17:19 INFO]: [DiscordSRV] - TC:📢╎announcements(1152817344138182657)
# [14:17:19 INFO]: [DiscordSRV] - TC:🌸╎ingame-relay🗨(1179704075248476170)
# [14:17:19 INFO]: [DiscordSRV] - TC:🛒╎shop-transactions(1171827779394875455)
# [14:17:19 INFO]: [DiscordSRV] - TC:🎮╎off-topic(1155496164834152528)
# [14:17:19 INFO]: [DiscordSRV] - TC:🎬╎clips-and-highlights(1152814325644415062)
# [14:17:19 INFO]: [DiscordSRV] - TC:dgc(1154696294871339100)
# [14:17:19 INFO]: [DiscordSRV] Console forwarding assigned to channel TC:server-console(1179704250822037565)
# [14:17:20 INFO]: [DiscordSRV] Enabling Essentials hook
# [14:17:20 INFO]: [DiscordSRV] Enabling LuckPerms hook
# [14:17:20 INFO]: [DiscordSRV] Enabling PlaceholderAPI hook
# [14:17:20 INFO]: [DiscordSRV] Enabling voice module
# [14:17:21 INFO]: [ChatItem] Loaded translation for en_gb.
# [14:17:21 INFO]: [EssentialsChat] Enabling EssentialsChat v2.20.1
# [14:17:21 INFO]: [EssentialsChat] Starting Metrics. Opt-out using the global bStats config.
# [14:17:21 INFO]: [BedrockParity] Enabling BedrockParity v2.0.0
# [14:17:21 INFO]: [BedrockParity] Sweeping Edge Book Fix in Anvil is enabled.
# [14:17:21 INFO]: [BedrockParity] Animating Heads for Bedrock Players is enabled.
# [14:17:21 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [14:17:21 INFO]: [ChatItem] §cA new version of ChatItem is available. §aClick here to download.
# [14:17:22 INFO]: [gg.playit.minecraft.PlayitKeysSetup] secret key found, checking
# [14:17:22 INFO]: [gg.playit.minecraft.PlayitKeysSetup] check secret
# [14:17:23 INFO]: [PlaceholderAPI] Placeholder expansion registration initializing...
# [14:17:23 INFO]: 0 placeholder hook(s) registered!
# [14:17:23 INFO]: [Geyser-Spigot] ******************************************
# [14:17:23 INFO]: [Geyser-Spigot]
# [14:17:23 INFO]: [Geyser-Spigot] Loading Geyser version 2.2.2-SNAPSHOT (git-master-f8e6d26)
# [14:17:23 INFO]: [Geyser-Spigot]
# [14:17:23 INFO]: [Geyser-Spigot] ******************************************
# [14:17:23 INFO]: [gg.playit.minecraft.PlayitKeysSetup] found minecraft java tunnel: mini-dozen.joinmc.link
# [14:17:23 INFO]: [gg.playit.minecraft.PlayitManager] keys and tunnel setup
# [14:17:23 INFO]: playit.gg: tunnel setup
# [14:17:23 INFO]: playit.gg: mini-dozen.joinmc.link
# [14:17:24 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [14:17:25 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [14:17:31 INFO]: [Geyser-Spigot] Started Geyser on 0.0.0.0:19132
# [14:17:31 INFO]: [Geyser-Spigot] Done (8.516s)! Run /geyser help for help!
# [14:17:32 INFO]: Starting GS4 status listener
# [14:17:32 INFO]: Thread Query Listener started
# [14:17:32 INFO]: Query running on 0.0.0.0:25565
# [14:17:32 INFO]: Running delayed init tasks
# [14:17:32 INFO]: [Essentials] Essentials found a compatible payment resolution method: Vault Compatibility Layer (v1.7.3-b131)!
# [14:17:32 INFO]: [Multiverse-Inventories] First run!
# [14:17:32 INFO]: Done (41.297s)! For help, type "help"
# [14:17:32 INFO]: Timings Reset
# [14:17:32 INFO]: [ViaVersion] Finished mapping loading, shutting down loader executor!
# [14:17:32 INFO]: [PlaceholderAPI] Successfully registered internal expansion: discordsrv [1.27.0]
# [14:17:32 INFO]: [Essentials] Fetching version information...
# [14:17:32 INFO]: [Vault] Checking for Updates ...
# [14:17:32 INFO]: [Vault] No new version available
# [14:17:32 INFO]: [DiscordSRV] Cleared all pre-existing slash commands in 1/1 guilds (0 cancelled)
# [14:17:32 WARN]: [ViaVersion] You are running a development version of the plugin, please report any bugs to GitHub.
# [14:17:36 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo > https://cdn.discordapp.com/attachments/1179704075248476170/1213128007581962330/IMG_20240301_211727.jpg?ex=65f4587f&is=65e1e37f&hm=c1a0beb5d2c6a563a06b6562db23c669aeb58387122e88af7b1080a58ee5cba6&
# [14:17:36 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo > @Arya @Doopos
# [14:17:36 INFO]: [DiscordSRV] Chat: [Discord | omega_super_sus] Dad > ayo sus
# [14:17:36 INFO]: [AngelChest] ========================================================
# [14:17:36 INFO]: [AngelChest] You are using the free version of AngelChest. There is
# [14:17:36 INFO]: [AngelChest] also a premium version available, called AngelChestPlus.
# [14:17:36 INFO]: [AngelChest] It includes TONS of new features and exclusive Discord
# [14:17:36 INFO]: [AngelChest] support. The free version will still receive bugfixes,
# [14:17:36 INFO]: [AngelChest] but there won't be ANY new features!
# [14:17:36 INFO]: [AngelChest] If you like AngelChest, you will LOVE AngelChestPlus, so
# [14:17:36 INFO]: [AngelChest] please consider upgrading! Thank you for using AngelChest.
# [14:17:36 INFO]: [AngelChest]
# [14:17:36 INFO]: [AngelChest] https://www.spigotmc.org/resources/88214
# [14:17:36 INFO]: [AngelChest] ========================================================
# [14:18:08 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > wait
# [14:18:17 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > 私を翻訳しないでください: https://www.youtube.com/watch?v=dQw4w9WgXcQ
# [14:18:18 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos (replying to Azzeherra Revo) > ak tau bang
# [14:18:18 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo > :ok:
# [14:18:36 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > brueh
# [14:18:43 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > bro did not translate japanese
# [14:18:43 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > fr
# [14:18:44 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > is ther essentials doop
# [14:18:51 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos (replying to Arya) > in what
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitManager] got new client: NewClient{connectAddr=209.25.141.181:60203, peerAddr=95.216.6.38:54163, claimAddress=209.25.140.2:42760, claimToken=[44, 0, 60, -47, 25, -115, -75, -21, 43, 95, -40, 6, 38, -45, -109, -38, 36, -81, 67, -89, 8, 101, -31, -29, -49, 0, 0, 0, 0, 0, 6, -18, 107, 0, 0, 0, 0, 0, 46, -103, 14, 98, 67, -89, 8, 0, 0, 0, 0, 14, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 125, 54, -74, -3, -102, -58, 80, 25, 15, -59, 83, 114, -52, -47, -95, 10], tunnelServerId=1, dataCenterId=14}
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitManager] starting tcp tunnel for client
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] start connection to /209.25.140.2:42760 to claim client
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to tunnel server, sending claim token
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] claim token sent
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connection to tunnel server has been established
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnection, LegacyPingHandler=class net.minecraft.server.network.LegacyPingHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.PacketSplitter, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.EnumProtocolDirection, PacketPrepender=class net.minecraft.network.PacketPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.NetworkManagerServer, NetworkManager=class net.minecraft.network.NetworkManager, HandshakeListener=class net.minecraft.server.network.HandshakeListener, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] failed to get Minecraft server from Bukkit.getServer()
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connecting to minecraft server at localhost/127.0.0.1:25565
# [14:18:55 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to local minecraft server
# [14:18:57 INFO]: UUID of player GamerDoop7 is 380f9ce9-1969-3b54-b310-951444ea6dc0
# [14:18:59 INFO]: GamerDoop7 joined the game
# [14:18:59 INFO]: GamerDoop7[/127.0.0.1:43932] logged in with entity id 292 at ([current]-305.70692622691075, 67.0, 5.398811546531377)
# [14:19:00 WARN]: [Essentials] Permissions lag notice with (LuckPermsHandler). Response took 25.664069ms. Summary: Getting prefix for GamerDoop7
# [14:19:00 WARN]: [Essentials] File motd.txt does not exist. Creating one for you.
# [14:19:06 INFO]: GamerDoop7 issued server command: /pl
# [14:19:09 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > the Server
# [14:19:14 INFO]: [Not Secure] <GamerDoop7> essentials yes
# [14:19:17 INFO]: [Not Secure] <GamerDoop7> but nick no
# [14:19:21 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo > https://cdn.discordapp.com/attachments/1179704075248476170/1213128447690547282/5200f4492cf85102ee8125b60dbfa4be.jpg?ex=65f458e8&is=65e1e3e8&hm=6d6d59e581d449977059b9b7134a2454b09c8e42ffbfe547c32908b919dfa2c7&
# [14:19:29 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > is essentials red
# [14:19:35 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > or something
# [14:19:43 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > it said i running unsupported mc ver
# [14:19:59 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > because i think essentials is 1.20.4 and my server is 1.20.2
# [14:20:10 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > is ther old ver download
# [14:20:12 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > i wonder
# [14:20:25 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > also Doop ss the output from /pl
# [14:20:47 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo (replying to Arya) > Emang gbs update versi server nya kah
# [14:20:53 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > from 6:49 to 7:21
# [14:20:56 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > speedrun to the nether
# [14:20:56 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > malas
# [14:21:01 INFO]: [Not Secure] <GamerDoop7> bruah
# [14:21:03 INFO]: GamerDoop7 issued server command: /pl
# [14:21:06 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > fr
# [14:21:11 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > doop pls
# [14:21:11 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo (replying to Arya) > Kalo malas ngapa buat server
# [14:21:18 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] Doopos > https://cdn.discordapp.com/attachments/1179704075248476170/1213128938784559175/image.png?ex=65f4595d&is=65e1e45d&hm=f713990747a4642482c2290715ecf6ca7bf0ed7a6738485fbc0e6f7a73a46692&
# [14:21:25 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [14:21:26 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > hm its not red
# [14:21:29 INFO]: [DiscordSRV] Chat: [Discord | moderator] Azzeherra Revo > Tinggal penced "apdet server version"
# [14:21:30 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > wdym by no /nick
# [14:21:31 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass0(PluginClassLoader.java:197) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass(PluginClassLoader.java:164) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:525) ~[?:?]
# 	... 25 more
# [14:21:32 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [14:21:32 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [14:21:32 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [14:21:32 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [14:21:33 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > i-
# [14:21:36 ERROR]: Could not pass event CraftItemEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [14:21:36 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# ...
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [15:14:40 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [15:14:41 ERROR]: Could not pass event InventoryClickEvent to BedrockParity v2.0.0
# java.lang.NoClassDefFoundError: org/geysermc/floodgate/api/FloodgateApi
# 	at com.tbyt.SweepingEdgeFix.findEnchant(SweepingEdgeFix.java:34) ~[BedrockParity.jar:?]
# 	at com.destroystokyo.paper.event.executor.asm.generated.GeneratedEventExecutor251.execute(Unknown Source) ~[?:?]
# 	at org.bukkit.plugin.EventExecutor$2.execute(EventExecutor.java:77) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at co.aikar.timings.TimedEventExecutor.execute(TimedEventExecutor.java:81) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:git-Paper-318]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperEventManager.callEvent(PaperEventManager.java:54) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.callEvent(PaperPluginManagerImpl.java:126) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:615) ~[paper-api-1.20.2-R0.1-SNAPSHOT.jar:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.handleContainerClick(ServerGamePacketListenerImpl.java:3108) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:58) ~[?:?]
# 	at net.minecraft.network.protocol.game.ServerboundContainerClickPacket.handle(ServerboundContainerClickPacket.java:23) ~[?:?]
# 	at net.minecraft.network.protocol.PacketUtils.lambda$ensureRunningOnSameThread$0(PacketUtils.java:53) ~[?:?]
# 	at net.minecraft.server.TickTask.run(TickTask.java:18) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.doRunTask(BlockableEventLoop.java:153) ~[?:?]
# 	at net.minecraft.util.thread.ReentrantBlockableEventLoop.doRunTask(ReentrantBlockableEventLoop.java:24) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.doRunTask(MinecraftServer.java:1324) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.d(MinecraftServer.java:193) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.pollTask(BlockableEventLoop.java:126) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.pollTaskInternal(MinecraftServer.java:1301) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.pollTask(MinecraftServer.java:1294) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.util.thread.BlockableEventLoop.managedBlock(BlockableEventLoop.java:136) ~[?:?]
# 	at net.minecraft.server.MinecraftServer.waitUntilNextTick(MinecraftServer.java:1272) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1160) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:315) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: java.lang.ClassNotFoundException: org.geysermc.floodgate.api.FloodgateApi
# 	... 25 more
# [15:14:41 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > wwait wait
# [15:14:43 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > nvm
# [15:14:45 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > ?purge 4
# [15:14:48 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > breh
# [15:14:51 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > naw we not
# [15:14:55 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > :moyai:
# [15:14:56 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > .
# [15:15:00 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > lollll
# [15:15:08 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > you know mincraft
# [15:15:11 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > does not register deletes
# [15:15:13 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > riht
# [15:15:19 INFO]: [Not Secure] <GamerDoop7> i see the world
# [15:15:23 INFO]: [Not Secure] <GamerDoop7> eheheh
# [15:15:31 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > .…
# [15:15:32 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > .…
# [15:15:49 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > https://cdn.discordapp.com/attachments/1179704075248476170/1213142658969501806/SPOILER_image.png?ex=65f46624&is=65e1f124&hm=414adf212aa1bbdfb457e691964de29a217c87cb31f6180a19b347bbbe4e292e&
# [15:15:52 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > but i think i hhave an idea
# [15:16:02 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > i think
# [15:16:06 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > goglle colab
# [15:16:09 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > github
# [15:16:11 INFO]: [Not Secure] <GamerDoop7> goggle
# [15:16:18 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > so you can edit it aand pull request it
# [15:16:22 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > lemme setup
# [15:16:38 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > it
# [15:16:39 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > up
# [15:17:21 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > ok
# [15:17:21 INFO]: [DiscordSRV] Chat: [Discord | manager] Paul > https://cdn.discordapp.com/attachments/1179704075248476170/1213143045751443507/Screenshot_20240229-184404.jpg?ex=65f46681&is=65e1f181&hm=074b24fcf2907362dd31254d08a4fea029b8a7c103e3fb43651e3d178f0d5ae2&
# [15:17:25 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > breuha
# [15:17:39 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [15:18:06 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > so smart
# [15:18:19 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > "aand" gets translated
# [15:20:48 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > what is your Github
# [15:20:58 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > GyaraDeez
# [15:21:17 INFO]: [DiscordSRV] Chat: [Discord | manager] Paul (replying to Translator) > i can barely understand laos language
# [15:21:17 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > lmao deez nu-
# [15:21:21 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber (replying to Paul) > breh
# [15:21:37 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > invited you to colabolatora
# [15:21:40 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [15:21:43 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya (replying to IFD Gaming | Youtuber) > ah-
# [15:22:31 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > Collaborators
# [15:25:40 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [15:26:59 INFO]: [Not Secure] <GamerDoop7> deddos
# [15:27:06 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > rippos
# [15:27:17 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > do yo get the invite tation
# [15:27:51 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > yeah
# [15:27:58 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > you accepd iit?
# [15:29:41 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [15:30:39 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > yes
# [15:31:10 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > dud hlep i forgor how to cretae a brach in gighhb:skull:
# [15:31:23 INFO]: [DiscordSRV] Chat: [Discord | manager] Paul > https://cdn.discordapp.com/attachments/1179704075248476170/1213146576780922930/IMG-20240213-WA0000.jpg?ex=65f469cb&is=65e1f4cb&hm=ef1ae1f10e24580f0d3b9e3321bf5d03ba244bb852a057b21be7d9a7f5f8778e&
# [15:31:35 INFO]: [DiscordSRV] Chat: [Discord | manager] Paul (replying to Arya) > github?
# [15:31:37 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya (replying to Arya) > @IFD Gaming | Youtuber :skull:
# [15:31:41 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > what
# [15:31:48 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > help:skull:
# [15:31:53 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > :skull::skull::skull:
# [15:33:41 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [15:33:57 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > https://docs.github.com/articles/creating-and-deleting-branches-within-your-repository
# [15:36:21 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > thers no that button
# [15:36:23 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > also am so bored rn
# [15:36:27 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > can  Collabolators doit
# [15:36:39 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > no you nneed to help me
# [15:36:42 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > first of all
# [15:36:48 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > disconect from tthe server
# [15:37:00 WARN]: [gg.playit.minecraft.PlayitTcpTunnel] failed to send data to tunnel
# [15:37:00 INFO]: GamerDoop7 lost connection: Disconnected
# [15:37:00 INFO]: GamerDoop7 left the game
# [15:37:01 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > second of all
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitManager] got new client: NewClient{connectAddr=209.25.141.181:60203, peerAddr=95.216.6.38:53555, claimAddress=209.25.140.2:42760, claimToken=[44, 0, 60, -47, 25, -115, -75, -21, 43, 95, -40, 6, 38, -47, 51, 76, 62, -30, 9, -89, 8, 101, -31, -10, 29, 0, 0, 0, 0, 0, 6, -18, 107, 0, 0, 0, 0, 0, 46, -103, 14, -37, 9, -89, 8, 0, 0, 0, 0, 14, 0, 0, 0, 0, 0, 0, 0, 3, 0, 1, -27, 69, 39, -54, 98, 61, 15, 60, -90, -99, 121, 123, -91, -128, -80, 4], tunnelServerId=3, dataCenterId=14}
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitManager] starting tcp tunnel for client
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] start connection to /209.25.140.2:42760 to claim client
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to tunnel server, sending claim token
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] claim token sent
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connection to tunnel server has been established
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnection, LegacyPingHandler=class net.minecraft.server.network.LegacyPingHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.PacketSplitter, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.EnumProtocolDirection, PacketPrepender=class net.minecraft.network.PacketPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.NetworkManagerServer, NetworkManager=class net.minecraft.network.NetworkManager, HandshakeListener=class net.minecraft.server.network.HandshakeListener, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] failed to get Minecraft server from Bukkit.getServer()
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connecting to minecraft server at localhost/127.0.0.1:25565
# [15:37:01 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to local minecraft server
# [15:37:18 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > help
# [15:37:43 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [15:38:28 INFO]: [DiscordSRV] Chat: [Discord | YouTuber] IFD Gaming | Youtuber > idk
# [15:38:44 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > try it
# >....
