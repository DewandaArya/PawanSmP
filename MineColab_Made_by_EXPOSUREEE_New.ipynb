# %% [markdown]
# <a href="https://colab.research.google.com/github/DewandaArya/PawanSmP/blob/main/MineColab_Made_by_EXPOSUREEE_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
# ```
# Create a Minecraft Server on Google Colab!
#
# The script below will initiate your server. First, you will need to create the server to be able to use it - don't worry, the scripts below will do the majority of the work for you. Perhaps you want to change the server's region, check below.
#
# Original: https://github.com/thecoder-001/MineColab

# %% [markdown]
# # **1º Create the Server (Only do this the first time)**
#
# The code below will create your server and accept the EULA. When you use these scripts, your server will be ready to start.

# %% [markdown]
# **Download the Minecraft Server**
#
# The code below will download Paper, a type of high-performance Vanilla server that allows the use of plugins. If you want to use another type of server.jar, put it in the Drive folder manually.
#
# The server files will be saved on your Google Drive (in the Google account you choose or are using).

# %%
# Change "1.20.1" to the desired version.
# Available tested versions:
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8
# Newer versions might work too, however this isn't guaranteed.

version = '1.20.2'

# Choose server type. Currently available versions:
# - paper (Most vanilla. It's the same as SPIGOT, bukkit, etc.)
# - forge (For using MODS. It's basically FORGE) [Note, installation takes approximately 10-15 minutes, wait for "COMPLETED" after executing the first step.]
# - fabric (For playing Fabric. It's an alternative to Forge)

server_type = 'paper'

# Print experimental build warning -- no longer needed
# if version == '1.18' and server_type == 'paper':
#  print("<!> Paper 1.18 builds are still experimental. Make regular Backups!")

from google.colab import drive
import requests
import json

drive.mount('/content/drive')

# Create the directory which will be used for the server
! mkdir "/content/drive/My Drive/Minecraft-server"
# %cd "/content/drive/My Drive/Minecraft-server"

# Internal init...

a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
#print(a.json()["builds"][-1])
b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
#print(b.json()["downloads"]["application"]["name"])
print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])

paperURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

forgeURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge-installer.jar'}
url = {
    'paper': (paperURL),
    'fabric': 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.7.4/fabric-installer-0.7.4.jar',
    'forge': (forgeURL)
    }

print('Downloading to Google Drive...')

r = requests.get(url[server_type])

if r.status_code == 200:
  with open('/content/drive/My Drive/Minecraft-server/' + jar_name[server_type], 'wb') as f:
    f.write(r.content)
else:
  print('Error '+ str(r.status_code) + '! Most likely you entered an unsupported version. Try running the code again if you think that shouldn\'t have happened.')

# Running specific install path.
if server_type == 'fabric':
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
  # %cd "/content/drive/My Drive/Minecraft-server"
  # !java -jar forge-installer.jar --installServer

# Saving config
colabconfig = {"server_type": server_type,
               "server_version": version}
json.dump(colabconfig, open("colabconfig.json",'w'))

print('Completed!')  # todo: Would show even after erroring.

# Please read the file stored in your server folder before running this command.
# Also, go to https://www.minecraft.net/en-us/eula to read Minecraft's EULA.

# Make sure Drive is mounted
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/Minecraft-server"
# !echo "eula=true" >> eula.txt
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Minecraft-server
# https://papermc.io/api/v2/projects/paper/versions/1.20.2/builds/318/downloads/paper-1.20.2-318.jar
# Downloading to Google Drive...
# Completed!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server

# %% [markdown]
# # **-> Start the Minecraft server - Use this whenever you want to open it.**
#
# You can change the REGION in the code below; this is important for LAG and PING. Use regions closest to you. The default region is the United States, which is not recommended for countries in South America or Spain. For these, you can use regions like 'sa' (Brazil) and 'eu' (Europe). You can change it in the code below where indicated.
#
# **IMPORTANT:**
#
# The IP will change every time you restart the server.
# You need to enter your Ngrok TOKEN below. Visit https://dashboard.ngrok.com/auth to obtain your token (you need to have an account created on Ngrok).
# To enter a command through the console, you can do it here. Basically, the section below will be your console (where you will enter commands and see logs).
# It is advisable to keep the Google Colab tab open so that the server does not close. It may ask you to solve a captcha from time to time.

# %%
import os
import re
import json
import glob

# Update the package lists
# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, you might receive stale packages"

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory to the Minecraft server folder on Google Drive
# %cd "/content/drive/My Drive/Minecraft-server"
# !ls #list the directory contents (to verify that working directory was changed)

# Import config file.
if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"} # using default, if config doesn't exist.
  json.dump(colabconfig, open("colabconfig.json",'w'))

# Install OpenJDK 17
# !wget -qO - https://adoptopenjdk.jfrog.io/adoptopenjdk/api/gpg/key/public | sudo apt-key add -
# !sudo add-apt-repository --yes https://adoptopenjdk.jfrog.io/adoptopenjdk/deb/ &>/dev/null || echo "Failed to add repo. Still can be ignored if openjdk17 gets installed."
if colabconfig["server_type"] == "forge":
   version = colabconfig["server_version"]
   if colabconfig["server_version"] < "1.17":
    # !sudo apt-get install openjdk-15-jre-headless &>/dev/null && echo "Yay! Openjdk15 has been successfully installed." || echo "Failed to install OpenJdk15."
   else:
    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."
else:
  # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."

#Perform java version check
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "17" :
  print("Openjdk17 is working correctly, you are good to go.")
else:
  print("Openjdk17 doesn't seem to be installed or isn't working, falling back to java", java_ver[0], ". You might experience reduced performance. Minecraft 1.17 and above might fail to launch.")

# Server jar names.
jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar'}
jar_name = jar_list[colabconfig["server_type"]]

# Java arguments.
if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = "" # aiker's flags might negatively impact performance on non-paper servers.
memory_allocation = "-Xms8704M -Xmx8704M"

# Choose the tunnel service you want to use
# Available options: ngrok, argo, playit
tunnel_service = "playit"
print("Using", tunnel_service)

# !sudo help

# !java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# apt cache successfully updated
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server
# banned-ips.json      config	      libraries        server.properties     world
# banned-players.json  current	      logs	       spigot.yml	     world_nether
# bukkit.yml	     current_nether   ops.json	       usercache.json	     world_the_end
# cache		     current_the_end  permissions.yml  version_history.json
# colabconfig.json     eula.txt	      plugins	       versions
# commands.yml	     help.yml	      server.jar       whitelist.json
# Yay! Openjdk17 has been successfully installed.
# Openjdk17 is working correctly, you are good to go.
# Using playit
# sudo: help: command not found
# Starting org.bukkit.craftbukkit.Main
# *** Warning, you've not updated in a while! ***
# *** Please download a new build as per instructions from https://papermc.io/downloads/paper ***
# System Info: Java 17 (OpenJDK 64-Bit Server VM 17.0.10+7-Ubuntu-122.04.1) Host: Linux 6.1.58+ (amd64)
# Loading libraries, please wait...
# [07:14:05 ERROR]: [DirectoryProviderSource] Error loading plugin: Directory 'plugins/zItemStacker.jar' failed to load!
# java.lang.RuntimeException: Directory 'plugins/zItemStacker.jar' failed to load!
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.registerProviders(FileProviderSource.java:59) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.lambda$registerProviders$1(DirectoryProviderSource.java:34) ~[paper-1.20.2.jar:git-Paper-318]
# 	at java.util.stream.ForEachOps$ForEachOp$OfRef.accept(ForEachOps.java:183) ~[?:?]
# 	at java.util.stream.ReferencePipeline$2$1.accept(ReferencePipeline.java:179) ~[?:?]
# 	at java.util.stream.ReferencePipeline$3$1.accept(ReferencePipeline.java:197) ~[?:?]
# 	at java.util.Iterator.forEachRemaining(Iterator.java:133) ~[?:?]
# 	at java.util.Spliterators$IteratorSpliterator.forEachRemaining(Spliterators.java:1845) ~[?:?]
# 	at java.util.stream.AbstractPipeline.copyInto(AbstractPipeline.java:509) ~[?:?]
# 	at java.util.stream.AbstractPipeline.wrapAndCopyInto(AbstractPipeline.java:499) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp.evaluateSequential(ForEachOps.java:150) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp$OfRef.evaluateSequential(ForEachOps.java:173) ~[?:?]
# 	at java.util.stream.AbstractPipeline.evaluate(AbstractPipeline.java:234) ~[?:?]
# 	at java.util.stream.ReferencePipeline.forEach(ReferencePipeline.java:596) ~[?:?]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.registerProviders(DirectoryProviderSource.java:32) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.DirectoryProviderSource.registerProviders(DirectoryProviderSource.java:14) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.util.EntrypointUtil.registerProvidersFromSource(EntrypointUtil.java:14) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.PluginInitializerManager.load(PluginInitializerManager.java:100) ~[paper-1.20.2.jar:git-Paper-318]
# 	at net.minecraft.server.Main.main(Main.java:134) ~[paper-1.20.2.jar:git-Paper-318]
# 	at org.bukkit.craftbukkit.Main.main(Main.java:325) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paperclip.Paperclip.lambda$main$0(Paperclip.java:42) ~[app:?]
# 	at java.lang.Thread.run(Thread.java:840) ~[?:?]
# Caused by: org.bukkit.plugin.InvalidPluginException: java.util.zip.ZipException: zip END header not found
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.checkUpdate(FileProviderSource.java:95) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.registerProviders(FileProviderSource.java:49) ~[paper-1.20.2.jar:git-Paper-318]
# 	... 20 more
# Caused by: java.util.zip.ZipException: zip END header not found
# 	at java.util.zip.ZipFile$Source.findEND(ZipFile.java:1633) ~[?:?]
# 	at java.util.zip.ZipFile$Source.initCEN(ZipFile.java:1641) ~[?:?]
# 	at java.util.zip.ZipFile$Source.<init>(ZipFile.java:1479) ~[?:?]
# 	at java.util.zip.ZipFile$Source.get(ZipFile.java:1441) ~[?:?]
# 	at java.util.zip.ZipFile$CleanableResource.<init>(ZipFile.java:718) ~[?:?]
# 	at java.util.zip.ZipFile.<init>(ZipFile.java:252) ~[?:?]
# 	at java.util.zip.ZipFile.<init>(ZipFile.java:181) ~[?:?]
# 	at java.util.jar.JarFile.<init>(JarFile.java:346) ~[?:?]
# 	at java.util.jar.JarFile.<init>(JarFile.java:317) ~[?:?]
# 	at java.util.jar.JarFile.<init>(JarFile.java:283) ~[?:?]
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.getPluginName(FileProviderSource.java:101) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.checkUpdate(FileProviderSource.java:76) ~[paper-1.20.2.jar:git-Paper-318]
# 	at io.papermc.paper.plugin.provider.source.FileProviderSource.registerProviders(FileProviderSource.java:49) ~[paper-1.20.2.jar:git-Paper-318]
# 	... 20 more
# [07:14:15 INFO]: Environment: Environment[accountsHost=https://api.mojang.com, sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [07:14:19 INFO]: Loaded 1174 recipes
# [07:14:20 INFO]: Loaded 1271 advancements
# [07:14:20 INFO]: Starting minecraft server version 1.20.2
# [07:14:20 WARN]: ****************************
# [07:14:20 WARN]: YOU ARE RUNNING THIS SERVER AS AN ADMINISTRATIVE OR ROOT USER. THIS IS NOT ADVISED.
# [07:14:20 WARN]: YOU ARE OPENING YOURSELF UP TO POTENTIAL RISKS WHEN DOING THIS.
# [07:14:20 WARN]: FOR MORE INFORMATION, SEE https://madelinemiller.dev/blog/root-minecraft-server/
# [07:14:20 WARN]: ****************************
# [07:14:20 INFO]: Loading properties
# [07:14:21 INFO]: This server is running Paper version git-Paper-318 (MC: 1.20.2) (Implementing API version 1.20.2-R0.1-SNAPSHOT) (Git: 9271ee7)
# [07:14:23 INFO]: Server Ping Player Sample Count: 12
# [07:14:23 INFO]: Using 4 threads for Netty based IO
# [07:14:24 WARN]: [!] The timings profiler has been enabled but has been scheduled for removal from Paper in the future.
#     We recommend installing the spark profiler as a replacement: https://spark.lucko.me/
#     For more information please visit: https://github.com/PaperMC/Paper/issues/8948
# [07:14:25 INFO]: [ChunkTaskScheduler] Chunk system is using 1 I/O threads, 1 worker threads, and gen parallelism of 1 threads
# [07:14:26 INFO]: Default game type: SURVIVAL
# [07:14:26 INFO]: Generating keypair
# [07:14:26 INFO]: Starting Minecraft server on *:25565
# [07:14:26 INFO]: Using epoll channel type
# [07:14:27 INFO]: Paper: Using libdeflate (Linux x86_64) compression from Velocity.
# [07:14:27 INFO]: Paper: Using OpenSSL 3.0.x (Linux x86_64) cipher from Velocity.
# [07:14:29 INFO]: [ViaVersion] Loading server plugin ViaVersion v4.9.3-SNAPSHOT
# [07:14:29 INFO]: [ViaVersion] ViaVersion 4.9.3-SNAPSHOT is now loaded. Registering protocol transformers and injecting...
# [07:14:30 INFO]: [ViaVersion] Loading block connection mappings ...
# [07:14:31 INFO]: [ViaVersion] Using FastUtil Long2ObjectOpenHashMap for block connections
# [07:14:31 INFO]: [LuckPerms] Loading server plugin LuckPerms v5.4.108
# [07:14:33 INFO]: [Vault] Loading server plugin Vault v1.7.3-b131
# [07:14:33 INFO]: [Multiverse-Core] Loading server plugin Multiverse-Core v4.3.12
# [07:14:33 INFO]: [PlaceholderAPI] Loading server plugin PlaceholderAPI v2.11.5
# [07:14:33 INFO]: [Essentials] Loading server plugin Essentials v2.20.1
# [07:14:33 INFO]: [floodgate] Loading server plugin floodgate v2.2.2-SNAPSHOT (b96-7f38765)
# [07:14:34 INFO]: [floodgate] Took 1,580ms to boot Floodgate
# [07:14:34 INFO]: [DiscordSRV] Loading server plugin DiscordSRV v1.27.0
# [07:14:34 INFO]: [Geyser-Spigot] Loading server plugin Geyser-Spigot v2.2.2-SNAPSHOT
# [07:14:35 INFO]: [Geyser-Spigot] Loading extensions...
# [07:14:35 INFO]: [Geyser-Spigot] Loaded 0 extension(s)
# [07:14:35 INFO]: [SkinsRestorer] Loading server plugin SkinsRestorer v15.0.7
# [07:14:35 INFO]: [TreeAssist] Loading server plugin TreeAssist v7.3.51
# [07:14:35 INFO]: [TreeAssist] Loading main config file: /config.yml
# [07:14:36 WARN]: [TreeAssist] Invalid Material in TreeConfig default.yml - Node Natural Blocks entry invalid: minecraft:short_grass
# [07:14:37 INFO]: [GriefPrevention] Loading server plugin GriefPrevention v16.18.1
# [07:14:37 INFO]: [ForestPlant] Loading server plugin ForestPlant vv1.0.7
# [07:14:37 INFO]: [SlimeablePistons] Loading server plugin SlimeablePistons v${1.1}
# [07:14:37 INFO]: [PlayerCheck] Loading server plugin PlayerCheck v1.0-SNAPSHOT
# [07:14:37 INFO]: [AngelChest] Loading server plugin AngelChest v11.0.1
# [07:14:38 INFO]: [Multiverse-Inventories] Loading server plugin Multiverse-Inventories v4.2.6
# [07:14:38 INFO]: [EssentialsChat] Loading server plugin EssentialsChat v2.20.1
# [07:14:38 INFO]: [ChatItem] Loading server plugin ChatItem v2.4.9
# [07:14:38 INFO]: [BedrockParity] Loading server plugin BedrockParity v2.0.0
# [07:14:38 INFO]: [playit-gg] Loading server plugin playit-gg v0.1.4
# [07:14:38 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [07:14:38 INFO]: [LuckPerms] Enabling LuckPerms v5.4.108
# [07:14:40 INFO]:         __
# [07:14:40 INFO]:   |    |__)   LuckPerms v5.4.108
# [07:14:40 INFO]:   |___ |      Running on Bukkit - Paper
# [07:14:40 INFO]:
# [07:14:40 INFO]: [LuckPerms] Loading configuration...
# [07:14:41 INFO]: [LuckPerms] Loading storage provider... [H2]
# [07:14:42 INFO]: [LuckPerms] Loading internal permission managers...
# [07:14:43 INFO]: [LuckPerms] Performing initial data load...
# [07:14:43 INFO]: [LuckPerms] Successfully enabled. (took 5766ms)
# [07:14:43 INFO]: [Vault] Enabling Vault v1.7.3-b131
# [07:14:43 INFO]: [Vault] [Economy] Essentials Economy found: Waiting
# [07:14:44 INFO]: [Vault] [Permission] SuperPermissions loaded as backup permission system.
# [07:14:44 INFO]: [Vault] Enabled Version 1.7.3-b131
# [07:14:44 INFO]: [LuckPerms] Registered Vault permission & chat hook.
# [07:14:44 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.7
# [07:14:47 INFO]: [SkinsRestorer] Running on Minecraft 1.20.2.
# [07:14:47 INFO]: [PlaceholderAPI] Successfully registered internal expansion: skinsrestorer [15.0.7]
# [07:14:47 INFO]: [SkinsRestorer] PlaceholderAPI expansion registered!
# [07:14:47 INFO]: [SkinsRestorer] Using paper join listener!
# [07:14:47 INFO]: [SkinsRestorer] Floodgate skin listener registered
# [07:14:47 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [07:14:47 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [07:14:47 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [07:14:47 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [07:14:47 INFO]: Preparing level "current"
# [07:14:47 INFO]: [SkinsRestorer] ----------------------------------------------
# [07:14:47 INFO]: [SkinsRestorer]     +==================+
# [07:14:47 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [07:14:47 INFO]: [SkinsRestorer]     |------------------|
# [07:14:47 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [07:14:47 INFO]: [SkinsRestorer]     +==================+
# [07:14:47 INFO]: [SkinsRestorer] ----------------------------------------------
# [07:14:47 INFO]: [SkinsRestorer]     Version: 15.0.7
# [07:14:47 INFO]: [SkinsRestorer]     Commit: 301d078
# [07:14:47 INFO]: [SkinsRestorer]     This is the latest version!
# [07:14:47 INFO]: [SkinsRestorer] ----------------------------------------------
# [07:14:49 INFO]: Preparing start region for dimension minecraft:overworld
# [07:14:49 INFO]: Time elapsed: 650 ms
# [07:14:49 INFO]: Preparing start region for dimension minecraft:the_nether
# [07:14:50 INFO]: Time elapsed: 164 ms
# [07:14:50 INFO]: Preparing start region for dimension minecraft:the_end
# [07:14:50 INFO]: Time elapsed: 201 ms
# [07:14:50 INFO]: [ViaVersion] Enabling ViaVersion v4.9.3-SNAPSHOT
# [07:14:50 INFO]: [ViaVersion] ViaVersion detected server version: 1.20.2 (764)
# [07:14:50 INFO]: [Multiverse-Core] Enabling Multiverse-Core v4.3.12
# [07:14:50 WARN]: [Multiverse-Core] "Multiverse-Core v4.3.12" has registered a listener for org.bukkit.event.entity.EntityCreatePortalEvent on method "public void com.onarandombox.MultiverseCore.listeners.MVPortalListener.entityPortalCreate(org.bukkit.event.entity.EntityCreatePortalEvent)", but the event is Deprecated. "Server performance will be affected"; please notify the authors [dumptruckman, Rigby, fernferret, lithium3141, main--].
# [07:14:50 INFO]: [Multiverse-Core] §aWe are aware of the warning about the deprecated event. There is no alternative that allows us to do what we need to do and performance impact is negligible. It is safe to ignore.
# [07:14:52 INFO]: [Multiverse-Core] 3 - World(s) loaded.
# [07:14:52 WARN]: [Multiverse-Core] Buscript failed to load! The script command will be disabled! If you would like not to see this message, use `/mv conf enablebuscript false` to disable Buscript from loading.
# [07:14:52 INFO]: [Multiverse-Core] Version 4.3.12 (API v24) Enabled - By dumptruckman, Rigby, fernferret, lithium3141 and main--
# [07:14:52 INFO]: [PlaceholderAPI] Enabling PlaceholderAPI v2.11.5
# [07:14:53 INFO]: [PlaceholderAPI] Fetching available expansion information...
# [07:14:54 INFO]: [Essentials] Enabling Essentials v2.20.1
# [07:14:54 ERROR]: [Essentials] You are running an unsupported server version!
# [07:14:55 INFO]: [Essentials] Attempting to convert old kits in config.yml to new kits.yml
# [07:14:55 INFO]: [Essentials] No kits found to migrate.
# [07:14:56 INFO]: [Essentials] Loaded 39094 items from items.json.
# [07:14:56 INFO]: [Essentials] Using locale en_US
# [07:14:57 INFO]: [Essentials] ServerListPingEvent: Spigot iterator API
# [07:14:57 INFO]: [Essentials] Starting Metrics. Opt-out using the global bStats config.
# [07:14:57 INFO]: [Vault] [Economy] Essentials Economy hooked.
# [07:14:57 INFO]: [Essentials] Using Vault based permissions (LuckPerms)
# [07:14:57 INFO]: [floodgate] Enabling floodgate v2.2.2-SNAPSHOT (b96-7f38765)
# [07:14:58 INFO]: [DiscordSRV] Enabling DiscordSRV v1.27.0
# [07:14:58 INFO]: [Geyser-Spigot] Enabling Geyser-Spigot v2.2.2-SNAPSHOT
# [07:14:58 INFO]: [TreeAssist] Enabling TreeAssist v7.3.51
# [07:14:58 INFO]: [TreeAssist] sending full Metrics! You can deactivate this in the config.yml
# [07:14:58 INFO]: [TreeAssist] debugging: off
# [07:14:58 INFO]: [PlaceholderAPI] Successfully registered internal expansion: ta [0.0.1]
# [07:14:58 INFO]: [GriefPrevention] Enabling GriefPrevention v16.18.1
# [07:14:58 INFO]: [TreeAssist] Checking for updates...
# [07:14:58 INFO]: [GriefPrevention] Finished loading configuration.
# [07:14:58 INFO]: [GriefPrevention] 1 total claims loaded.
# [07:14:59 INFO]: [GriefPrevention] Customizable messages loaded.
# [07:14:59 INFO]: [GriefPrevention] Finished loading data (File Mode).
# [07:14:59 INFO]: [GriefPrevention] Boot finished.
# [07:14:59 INFO]: [ForestPlant] Enabling ForestPlant vv1.0.7
# [07:14:59 INFO]: [ForestPlant] INFO : Using lang 'en'
# [07:14:59 INFO]: [ForestPlant] INFO : messages_en.yml loaded successfully!
# [07:15:00 INFO]: [SlimeablePistons] Enabling SlimeablePistons v${1.1}
# [07:15:00 INFO]: [PlayerCheck] Enabling PlayerCheck v1.0-SNAPSHOT
# [07:15:00 INFO]: [AngelChest] Enabling AngelChest v11.0.1
# [07:15:00 INFO]: [DiscordSRV] DiscordSRV is up-to-date. (6405e850eea61a4b9bf4f0d0cbb80fe20b3cfb90)
# [07:15:00 INFO]: [AngelChest] groups.yml does not exist, skipping custom group settings.
# [07:15:00 INFO]: [AngelChest] blacklist.yml does not exist, disabling item blacklist.
# [07:15:00 INFO]: [AngelChest] Not using premium version, disabling Graveyards feature
# [07:15:00 INFO]: [PlaceholderAPI] Successfully registered internal expansion: angelchest [GENERIC]
# [07:15:01 INFO]: [AngelChest] Successfully hooked into Vault and the EconomyProvider, enabling economy functions.
# [07:15:01 INFO]: [AngelChest] [ACF] Enabled Asynchronous Tab Completion Support!
# [07:15:01 INFO]: [AngelChest] Successfully enabled AngelChest v11.0.1 (Premium: false)
# [07:15:01 INFO]: [Multiverse-Inventories] Enabling Multiverse-Inventories v4.2.6
# [07:15:01 INFO]: [DiscordSRV] [JDA] Login Successful!
# [07:15:01 INFO]: [Multiverse-Inventories 4.2.6] enabled.
# [07:15:01 INFO]: [EssentialsChat] Enabling EssentialsChat v2.20.1
# [07:15:01 INFO]: [EssentialsChat] Starting Metrics. Opt-out using the global bStats config.
# [07:15:01 INFO]: [ChatItem] Enabling ChatItem v2.4.9
# [07:15:01 INFO]: [ChatItem] Detected server version: v1_20
# [07:15:01 INFO]: [ChatItem] Loading own packet system.
# [07:15:02 INFO]: [ChatItem] Loaded 3 getter for base components.
# [07:15:02 INFO]: [DiscordSRV] [JDA] Connected to WebSocket
# [07:15:02 INFO]: [ChatItem] Save method founded: b. Use ComponentBuilder's method.
# [07:15:02 INFO]: [ChatItem] Manager automatically chosen: PacketEditing (packet), ChatListener (chat)
# [07:15:02 INFO]: [ChatItem] Load DiscordSRV support.
# [07:15:02 INFO]: [DiscordSRV] [JDA] Finished Loading!
# [07:15:03 INFO]: [DiscordSRV] Found server G:🌸Pawan'SMP(1152814325111722115)
# [07:15:03 INFO]: [DiscordSRV] - TC:moderator-only(1170360612866502776)
# [07:15:03 INFO]: [DiscordSRV] - TC:deathboard-deathskul(1213396173168320522)
# [07:15:03 INFO]: [DiscordSRV] - TC:server-console(1179704250822037565)
# [07:15:03 INFO]: [DiscordSRV] - TC:📢╎announcements(1152817344138182657)
# [07:15:03 INFO]: [DiscordSRV] - TC:ℹ╎info(1152856245498294282)
# [07:15:03 INFO]: [DiscordSRV] - TC:🌸╎ingame-relay🗨(1179704075248476170)
# [07:15:03 INFO]: [DiscordSRV] - TC:🛒╎shop-transactions(1171827779394875455)
# [07:15:03 INFO]: [DiscordSRV] - TC:🎮╎off-topic(1155496164834152528)
# [07:15:03 INFO]: [DiscordSRV] - TC:🎬╎clips-and-highlights(1152814325644415062)
# [07:15:03 INFO]: [DiscordSRV] - TC:dgc(1154696294871339100)
# [07:15:03 INFO]: [DiscordSRV] Console forwarding assigned to channel TC:server-console(1179704250822037565)
# [07:15:03 INFO]: [DiscordSRV] Enabling Essentials hook
# [07:15:03 INFO]: [DiscordSRV] Enabling LuckPerms hook
# [07:15:03 INFO]: [DiscordSRV] Enabling PlaceholderAPI hook
# [07:15:03 INFO]: [DiscordSRV] Enabling voice module
# [07:15:04 INFO]: [ChatItem] Loaded translation for en_gb.
# [07:15:04 INFO]: [BedrockParity] Enabling BedrockParity v2.0.0
# [07:15:04 INFO]: [BedrockParity] Sweeping Edge Book Fix in Anvil is enabled.
# [07:15:04 INFO]: [BedrockParity] Animating Heads for Bedrock Players is enabled.
# [07:15:04 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [07:15:04 INFO]: [ChatItem] §cA new version of ChatItem is available. §aClick here to download.
# [07:15:05 INFO]: [gg.playit.minecraft.PlayitKeysSetup] secret key found, checking
# [07:15:05 INFO]: [gg.playit.minecraft.PlayitKeysSetup] check secret
# [07:15:08 INFO]: [PlaceholderAPI] Placeholder expansion registration initializing...
# [07:15:08 INFO]: [Geyser-Spigot] ******************************************
# [07:15:08 INFO]: [Geyser-Spigot]
# [07:15:08 INFO]: [Geyser-Spigot] Loading Geyser version 2.2.2-SNAPSHOT (git-master-f8e6d26)
# [07:15:08 INFO]: [Geyser-Spigot]
# [07:15:08 INFO]: [Geyser-Spigot] ******************************************
# [07:15:09 INFO]: [gg.playit.minecraft.PlayitKeysSetup] found minecraft java tunnel: mini-dozen.joinmc.link
# [07:15:09 INFO]: [gg.playit.minecraft.PlayitManager] keys and tunnel setup
# [07:15:09 INFO]: playit.gg: tunnel setup
# [07:15:09 INFO]: playit.gg: mini-dozen.joinmc.link
# [07:15:09 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [07:15:25 INFO]: [Geyser-Spigot] Started Geyser on 0.0.0.0:19132
# [07:15:26 INFO]: [Geyser-Spigot] Done (17.218s)! Run /geyser help for help!
# [07:15:26 INFO]: Starting GS4 status listener
# [07:15:26 INFO]: Thread Query Listener started
# [07:15:26 INFO]: Query running on 0.0.0.0:25565
# [07:15:26 INFO]: Running delayed init tasks
# [07:15:26 INFO]: [Essentials] Essentials found a compatible payment resolution method: Vault Compatibility Layer (v1.7.3-b131)!
# [07:15:26 INFO]: 0 placeholder hook(s) registered!
# [07:15:26 INFO]: [ViaVersion] Finished mapping loading, shutting down loader executor!
# [07:15:26 INFO]: [Multiverse-Inventories] First run!
# [07:15:26 INFO]: Done (65.829s)! For help, type "help"
# [07:15:26 INFO]: Timings Reset
# [07:15:26 INFO]: [Essentials] Fetching version information...
# [07:15:26 INFO]: [Vault] Checking for Updates ...
# [07:15:26 INFO]: [PlaceholderAPI] Successfully registered internal expansion: discordsrv [1.27.0]
# [07:15:26 INFO]: [Vault] No new version available
# [07:15:26 WARN]: [ViaVersion] You are running a development version of the plugin, please report any bugs to GitHub.
# [07:15:26 INFO]: [DiscordSRV] Cleared all pre-existing slash commands in 1/1 guilds (0 cancelled)
# [07:15:31 INFO]: [AngelChest] ========================================================
# [07:15:31 INFO]: [AngelChest] You are using the free version of AngelChest. There is
# [07:15:31 INFO]: [AngelChest] also a premium version available, called AngelChestPlus.
# [07:15:31 INFO]: [AngelChest] It includes TONS of new features and exclusive Discord
# [07:15:31 INFO]: [AngelChest] support. The free version will still receive bugfixes,
# [07:15:31 INFO]: [AngelChest] but there won't be ANY new features!
# [07:15:31 INFO]: [AngelChest] If you like AngelChest, you will LOVE AngelChestPlus, so
# [07:15:31 INFO]: [AngelChest] please consider upgrading! Thank you for using AngelChest.
# [07:15:31 INFO]: [AngelChest]
# [07:15:31 INFO]: [AngelChest] https://www.spigotmc.org/resources/88214
# [07:15:31 INFO]: [AngelChest] ========================================================
# [07:16:18 INFO]: The port you are testing with (50795) is not the same as you set in your Geyser configuration (19132)
# [07:16:18 INFO]: Re-run the command with the port in the config, or change the `bedrock` `port` in the config.
# [07:16:18 INFO]: Testing server connection to 147.185.221.18 with port: 50795 now. Please wait...
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitManager] got new client: NewClient{connectAddr=147.185.221.18:50795, peerAddr=188.165.222.136:44448, claimAddress=209.25.140.2:43783, claimToken=[44, 0, 60, -109, -71, -35, 18, -58, 107, -68, -91, -34, -120, -83, -96, 35, -107, -89, 34, -85, 7, 101, -28, 35, -59, 0, 0, 0, 0, 0, 6, -18, 107, 0, 0, 0, 0, 0, 46, -103, 14, -1, 34, -85, 7, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, -21, 35, 94, -14, -4, 53, -42, 115, 78, -40, 121, -24, -55, 80, -85, 99], tunnelServerId=1, dataCenterId=5}
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitManager] starting tcp tunnel for client
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] start connection to /209.25.140.2:43783 to claim client
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to tunnel server, sending claim token
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] claim token sent
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connection to tunnel server has been established
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] Reflect: ReflectionHelper{ServerConnection=class net.minecraft.server.network.ServerConnection, LegacyPingHandler=class net.minecraft.server.network.LegacyPingHandler, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=class net.minecraft.network.PacketSplitter, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=class net.minecraft.network.protocol.EnumProtocolDirection, PacketPrepender=class net.minecraft.network.PacketPrepender, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=class net.minecraft.network.NetworkManagerServer, NetworkManager=class net.minecraft.network.NetworkManager, HandshakeListener=class net.minecraft.server.network.HandshakeListener, PacketListener=interface net.minecraft.network.PacketListener, CraftServer=null}
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] failed to get Minecraft server from Bukkit.getServer()
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connecting to minecraft server at localhost/127.0.0.1:25565
# [07:16:21 INFO]: [gg.playit.minecraft.PlayitTcpTunnel] connected to local minecraft server
# [07:16:23 INFO]: Your server is likely unreachable from outside the network!
# [07:16:23 INFO]: Got the error message: Connection timed out
# [07:16:23 INFO]: If you still face issues, check the setup guide for instructions: https://wiki.geysermc.org/geyser/setup/
# [07:16:23 INFO]: If that does not work, see https://wiki.geysermc.org/geyser/fixing-unable-to-connect-to-world/, or contact us on Discord: https://discord.gg/geysermc
# [07:19:10 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:23:12 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:24:44 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > ?purge 6
# [07:27:14 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:31:17 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:33:40 INFO]: Collecting dump info
# [07:33:41 INFO]: Uploading dump
# [07:33:41 INFO]: We've made a dump with useful information, report your issue and provide this url: https://dump.geysermc.org/JmnXcN2Oy00ODnCg2y5ywgQ3Wz9c7JW2
# [07:34:10 INFO]: [DiscordSRV] Chat: [Discord | ᴀʀʏᴀ] Arya > https://dump.geysermc.org/JmnXcN2Oy00ODnCg2y5ywgQ3Wz9c7JW2
# [07:35:19 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:39:21 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:43:23 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:47:25 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:51:27 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:55:30 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [07:59:32 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:03:34 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:07:36 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:11:38 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:15:40 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:19:43 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:23:45 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:27:47 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:31:49 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:35:51 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:39:53 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:43:55 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:47:58 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:52:00 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [08:56:02 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [09:00:04 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [09:04:06 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [09:08:08 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [09:12:11 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# >....
